# %% [markdown]
# # Generating Fractal Patterns

# %%
# Import turtle library for drawing
from turtle import *
import matplotlib.pyplot as plt

import numpy as np
import random

# %% [markdown]
# ## Sierpiński Triangle

# %%
# Set up turtle
tur = Turtle()
tur.hideturtle()

# Set up screen
screen = Screen()
screen.setworldcoordinates(-1.268,-0.268,1.268,2)

# Set triangle vertices
tri_points = [(-1., 0.), (1., 0.), (0., np.sqrt(3))]

# Move turtle to a random starting point
tur.penup()
tur.hideturtle()
tur.setpos((np.random.uniform(-1, 1), np.random.uniform(0, np.sqrt(3))))

# Loop to create Sierpinski's triangle pattern
n_iter = 10000
for _ in range(n_iter):
    i = np.random.randint(0,len(tri_points))
    tur.hideturtle()
    tur.penup()
    tur.speed(0)
    
    tur.goto(tuple(n/2 for n in tur.pos() + tri_points[i]))
    tur.dot(0.1, 'blue')

# %% [markdown]
# ## Barnsley's Fern

# %%
# Set up turtle
size = 4
color = 'green'

tur = Turtle()
tur.dot(size, color)

# Set up screen
screen = Screen()
screen.setworldcoordinates(-2.3820, -0.2, 2.8558, 10.1983)

# Perform affine transformations to generate the fractal
n_iter = 100000
for _ in range(n_iter):
    x0, y0 = tur.pos()
    
    p = random.uniform(0, 100)
    if p < 1.0:
        x = 0
        y = 0.16 * y0
    elif p < 86.0:
        x = 0.85 * x0 + 0.04 * y0
        y = -0.04 * x0 + 0.85 * y0 + 1.60
    elif p < 93.0:
        x = 0.20 * x0 - 0.26 * y0
        y = 0.23 * x0 + 0.22 * y0 + 1.60
    else:
        x = -0.15 * x0 + 0.28 * y0
        y = 0.26 * x0 + 0.24 * y0 + 0.44
    
    tur.shape('circle')
    tur.color('green')
    
    tur.penup()
    tur.speed(0)
    tur.goto(x, y)
    tur.dot(size, color)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-56a1848e19e7> in <module>()
#      35     tur.speed(0)
#      36     tur.goto(x, y)
# ---> 37     tur.dot(size, color)
#
# /home/rei/anaconda3/lib/python3.6/turtle.py in dot(self, size, *color)
#    3391                 self.pensize(size)
#    3392                 self.pencolor(color)
# -> 3393                 self.forward(0)
#    3394             finally:
#    3395                 self.pen(pen)
#
# /home/rei/anaconda3/lib/python3.6/turtle.py in forward(self, distance)
#    1635         (-50.00,0.00)
#    1636         """
# -> 1637         self._go(distance)
#    1638
#    1639     def back(self, distance):
#
# /home/rei/anaconda3/lib/python3.6/turtle.py in _go(self, distance)
#    1603         """move turtle forward by specified distance"""
#    1604         ende = self._position + self._orient * distance
# ...

# %%
# With matplotlib
n_iter = 1000000
xs = [0]
ys = [0]

for n in range(n_iter):
    p = random.uniform(0, 100)
    if p < 1.0:
        x = 0
        y = 0.16 * ys[n-1]
    elif p < 86.0:
        x = 0.85 * xs[n-1] + 0.04 * ys[n-1]
        y = -0.04 * xs[n-1] + 0.85 * ys[n-1] + 1.60
    elif p < 93.0:
        x = 0.20 * xs[n-1] - 0.26 * ys[n-1]
        y = 0.23 * xs[n-1] + 0.22 * ys[n-1] + 1.60
    else:
        x = -0.15 * xs[n-1] + 0.28 * ys[n-1]
        y = 0.26 * xs[n-1] + 0.24 * ys[n-1] + 0.44
    xs.append(x)
    ys.append(y)

fig = plt.figure(figsize = (10, 10))
_ = plt.axis('off')
_ = plt.scatter(xs, ys, s=0.1, color='g', marker='.')

_ = plt.show()
fig.savefig('Barnsley_fern.png')
